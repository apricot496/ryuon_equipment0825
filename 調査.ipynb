# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
DB_PATH = "equipment.db"
conn = sqlite3.connect(DB_PATH)
sql = """
SELECT 
 * 
FROM eqipment_img_scraping
WHERE 装備名 == 'カムロップポシェット'
"""
df = pd.read_sql(sql, conn)
df
# Out:
#     id         装備名 レアリティ                 画像名    体力   攻撃力    防御力   会心率   回避率  \
# 0    4  カムロップポシェット   SSR  カムロップポシェット_SSR.png  None  None  215.0  None  None
# 1  679  カムロップポシェット   SSR  カムロップポシェット_SSR.png  None  None  215.0  None  None
#
#     命中率                      アビリティ  新規フラグ  URL_Number  \
# 0  None   残HP30％以下の時にクールタイム回復を8％加速      0         130
# 1  None  残HP30％以下の時にスキルクールタイムを8％加速      0         789
#
#                                              IMG_URL
# 0  https://raw.githubusercontent.com/apricot496/r...
# 1  https://raw.githubusercontent.com/apricot496/r...

# %%
DB_PATH = "equipment.db"
conn = sqlite3.connect(DB_PATH)
sql = """
WITH new_eqipment_img_scraping AS (
    SELECT DISTINCT
        装備名,
        IMG_URL,
        レアリティ
    FROM eqipment_img_scraping
),
all_equipment AS (
    SELECT * FROM 'ur武器'
    UNION ALL
    SELECT * FROM 'ksr武器'
    UNION ALL
    SELECT * FROM 'ssr武器'
    UNION ALL
    SELECT * FROM 'ur防具'
    UNION ALL
    SELECT * FROM 'ksr防具'
    UNION ALL
    SELECT * FROM 'ssr防具'
    UNION ALL
    SELECT * FROM 'ur装飾'
    UNION ALL
    SELECT * FROM 'ksr装飾'
    UNION ALL
    SELECT * FROM 'ssr装飾'
)
SELECT 
    e.装備名,
    e.レアリティ,
    e.IMG_URL,
    s.装備番号
FROM new_eqipment_img_scraping AS e
LEFT JOIN all_equipment AS s
  ON s.装備名 = e.装備名
 AND s.レアリティ = e.レアリティ
WHERE s.装備番号 IS NULL
"""
df = pd.read_sql(sql, conn)

df = pd.read_sql(sql, conn)
df
# Out:
#            装備名 レアリティ                                            IMG_URL  装備番号
# 0        怨恨バット  None  https://raw.githubusercontent.com/apricot496/r...  None
# 1     羅刹のトンファー  None  https://raw.githubusercontent.com/apricot496/r...  None
# 2       堪忍のサラシ  None  https://raw.githubusercontent.com/apricot496/r...  None
# 3   上山試作型インソール  None  https://raw.githubusercontent.com/apricot496/r...  None
# 4        水神ブレス  None  https://raw.githubusercontent.com/apricot496/r...  None
# 5     不動明王のお守り  None  https://raw.githubusercontent.com/apricot496/r...  None
# 6      Model14   SSR  https://raw.githubusercontent.com/apricot496/r...  None
# 7   シンジのロングコート   SSR  https://raw.githubusercontent.com/apricot496/r...  None
# 8     亜門のコート・極   KSR  https://raw.githubusercontent.com/apricot496/r...  None
# 9        亜門のドス   KSR  https://raw.githubusercontent.com/apricot496/r...  None
# 10      城戸のスーツ   KSR  https://raw.githubusercontent.com/apricot496/r...  None
# 11  エージェントシューズ   KSR  https://raw.githubusercontent.com/apricot496/r...  None
# 12      鬼仁会の代紋   KSR  https://raw.githubusercontent.com/apricot496/r...  None
# 13    リバイバルマイク    UR  https://raw.githubusercontent.com/apricot496/r...  None
# 14        None  None                                               None  None
